# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Document

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\Innomatics\Machine_Learning\Project_ML\Healthcare_insurance\insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# #### Checking Missing Values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# #### Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %% [markdown]
# #### Treating Duplictaes

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %% [markdown]
# ### Outliers Checking and Handling

# %%
df.select_dtypes(include=["int64","float64"])
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
df.select_dtypes(["object"])
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
plt.boxplot([df.charges])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a30593d40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a305c4260>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a302e1100>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a305c47a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a305c4a10>],
#  'means': []}

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.select_dtypes(["int","float"])
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
df.boxplot(column=["age","bmi","children","charges"])
# Out:
# <Axes: >

# %%
plt.tight_layout()
plt.figure(figsize=(10,8))
# First plot
plt.subplot(2, 2, 1)
plt.boxplot(df["age"])
plt.title("Age")

# Second plot
plt.subplot(2, 2, 2)
plt.boxplot(df["bmi"])
plt.title("BMI")

# Third plot
plt.subplot(2,2,3)
plt.boxplot(df["children"])
plt.title("Childrens")

# Fourth plot
plt.subplot(2,2,4)
plt.boxplot(df["charges"])
plt.title("Charges")

plt.show()

# %% [markdown]
# ### Outliers Detecting For column Age

# %%
plt.boxplot(df["age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a31134890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a31134dd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a31134680>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a31135250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a311354f0>],
#  'means': []}

# %%
Q1=df["age"].quantile(0.25)
Q3=df["age"].quantile(0.75)
IQR=Q3-Q1

lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR

outliers=df[(df["age"]<lower_limit) | (df["age"]>upper_limit)]
outliers
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %% [markdown]
# ### Outliers Detecting For column BMI

# %%
plt.boxplot(df["bmi"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a3117ed50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a3117f2f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a3117eab0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a3117f740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a3117f9e0>],
#  'means': []}

# %%
Q1=df["bmi"].quantile(0.25)
Q3=df["bmi"].quantile(0.75)
IQR=Q3-Q1

lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR

outliers=df[(df["bmi"]<lower_limit) | (df["bmi"]>upper_limit)]
outliers
# Out:
#       age     sex    bmi  children smoker     region      charges
# 116    58    male  49.06         0     no  southeast  11381.32540
# 286    46  female  48.07         2     no  northeast   9432.92530
# 401    47    male  47.52         1     no  southeast   8083.91980
# 543    54  female  47.41         0    yes  southeast  63770.42801
# 847    23    male  50.38         1     no  southeast   2438.05520
# 860    37  female  47.60         2    yes  southwest  46113.51100
# 1047   22    male  52.58         1    yes  southeast  44501.39820
# 1088   52    male  47.74         1     no  southeast   9748.91060
# 1317   18    male  53.13         0     no  southeast   1163.46270

# %%
lower_limit
# Out:
# 13.674999999999994

# %%
upper_limit
# Out:
# 47.31500000000001

# %%
outliers
# Out:
#       age     sex    bmi  children smoker     region      charges
# 116    58    male  49.06         0     no  southeast  11381.32540
# 286    46  female  48.07         2     no  northeast   9432.92530
# 401    47    male  47.52         1     no  southeast   8083.91980
# 543    54  female  47.41         0    yes  southeast  63770.42801
# 847    23    male  50.38         1     no  southeast   2438.05520
# 860    37  female  47.60         2    yes  southwest  46113.51100
# 1047   22    male  52.58         1    yes  southeast  44501.39820
# 1088   52    male  47.74         1     no  southeast   9748.91060
# 1317   18    male  53.13         0     no  southeast   1163.46270

# %%
outliers.shape
# Out:
# (9, 7)

# %% [markdown]
# ### Outliers Detecting For column Children

# %%
plt.boxplot(df["children"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a311e7290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a311e76b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a311e7020>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a311e7c20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a311e7ec0>],
#  'means': []}

# %%
Q1=df["children"].quantile(0.25)
Q3=df["children"].quantile(0.75)
IQR=Q3-Q1

lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR

outliers=df[(df["children"]<lower_limit) | (df["children"]>upper_limit)]
outliers
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %% [markdown]
# ### Outliers Detecting For column charges

# %%
plt.boxplot(df["charges"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18a31279820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18a31279d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18a312795b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18a31279e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18a3127a0f0>],
#  'means': []}

# %%
Q1=df["charges"].quantile(0.25)
Q3=df["charges"].quantile(0.75)

IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR

outliers=df[(df["charges"]<lower_limit) | (df["charges"]>upper_limit)]
outliers
# Out:
#       age     sex     bmi  children smoker     region      charges
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 29     31    male  36.300         2    yes  southwest  38711.00000
# 30     22    male  35.600         0    yes  southwest  35585.57600
# ...   ...     ...     ...       ...    ...        ...          ...
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1303   43    male  27.800         0    yes  southwest  37829.72420
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1323   42  female  40.370         2    yes  southeast  43896.37630
#
# [139 rows x 7 columns]

# %%
## Non Outliers Rows of Column "charges"
non_outliers=df[(df["charges"]>=lower_limit) & (df["charges"]<=upper_limit)]
non_outliers
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1198 rows x 7 columns]

# %%
df.shape
# Out:
# (1337, 7)

# %%
Q3
# Out:
# 16657.71745

# %% [markdown]
# #### Outliers Checking Of All Columns

# %%
num_df=df.select_dtypes(include=["int64","float64"])
Q1 = num_df.quantile(0.25)
Q3 = num_df.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = ((num_df < (Q1 - 1.5 * IQR)) | (num_df > (Q3 + 1.5 * IQR)))
print("Number of outliers per column:")
print(outliers_iqr.sum())
# Out:
# Number of outliers per column:
# age           0
# bmi           9
# children      0
# charges     139
# dtype: int64

# %%
outliers_iqr
# Out:
#         age    bmi  children  charges
# 0     False  False     False    False
# 1     False  False     False    False
# 2     False  False     False    False
# 3     False  False     False    False
# 4     False  False     False    False
# ...     ...    ...       ...      ...
# 1333  False  False     False    False
# 1334  False  False     False    False
# 1335  False  False     False    False
# 1336  False  False     False    False
# 1337  False  False     False    False
#
# [1337 rows x 4 columns]

# %%
num_df
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %% [markdown]
# ### Extracting Non Outliers Rows

# %%
num_df=df.select_dtypes(include=["int64","float64"])
Q1 = num_df.quantile(0.25)
Q3 = num_df.quantile(0.75)
IQR = Q3 - Q1

non_outliers_iqr = ((num_df > (Q1 - 1.5 * IQR)) & (num_df < (Q3 + 1.5 * IQR)))
print("Number of outliers per column:")
print(non_outliers_iqr.sum())
# Out:
# Number of outliers per column:
# age         1337
# bmi         1328
# children    1319
# charges     1198
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
plt.tight_layout()
plt.figure(figsize=(10,8))
# First plot
plt.subplot(2, 2, 1)
plt.hist(df["age"])
plt.title("Age")

# Second plot
plt.subplot(2, 2, 2)
plt.hist(df["bmi"])
plt.title("BMI")

# Third plot
plt.subplot(2,2,3)
plt.hist(df["children"])
plt.title("Childrens")

# Fourth plot
plt.subplot(2,2,4)
plt.hist(df["charges"])
plt.title("Charges")

plt.show()

# %%
df.select_dtypes(include="object")
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
plt.tight_layout()
plt.figure(figsize=(12,12))
# First plot
plt.subplot(2, 2, 1)
df["sex"].value_counts().plot(kind="bar")
plt.title("Gender")

# Second plot
plt.subplot(2, 2, 2)
df["smoker"].value_counts().plot(kind="bar")
plt.title("Smoker and Non Smokers")

# Third plot
plt.subplot(2,2,3)
df["region"].value_counts().plot(kind="bar")
plt.title("Region")
# Out:
# Text(0.5, 1.0, 'Region')

# %%
plt.tight_layout()
plt.figure(figsize=(12,12))
# First plot
plt.subplot(2, 2, 1)
df["sex"].value_counts().plot(kind="pie")
plt.title("Gender")

# Second plot
plt.subplot(2, 2, 2)
df["smoker"].value_counts().plot(kind="pie")
plt.title("Smoker and Non Smokers")

# Third plot
plt.subplot(2,2,3)
df["region"].value_counts().plot(kind="pie")
plt.title("Region")
# Out:
# Text(0.5, 1.0, 'Region')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12))

# First plot
plt.subplot(2, 2, 1)
sns.countplot(x="sex", data=df)
plt.title("Gender")

# Second plot
plt.subplot(2, 2, 2)
sns.countplot(x="smoker", data=df)
plt.title("Smoker and Non-Smokers")

# Third plot
plt.subplot(2, 2, 3)
sns.countplot(x="region", data=df)
plt.title("Region")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue="charges")
plt.show()

# %% [markdown]
# ## Univariate Analysis - Statistical Non Visual Analysis

# %%
numeric_data=df.select_dtypes(include="number")
categorical_data=df.select_dtypes(include="object")

# %%
numeric_data.head()
# Out:
#    age     bmi  children      charges
# 0   19  27.900         0  16884.92400
# 1   18  33.770         1   1725.55230
# 2   28  33.000         3   4449.46200
# 3   33  22.705         0  21984.47061
# 4   32  28.880         0   3866.85520

# %%
categorical_data.head()
# Out:
#       sex smoker     region
# 0  female    yes  southwest
# 1    male     no  southeast
# 2    male     no  southeast
# 3    male     no  northwest
# 4    male     no  northwest

# %% [markdown]
# ## Univariate Analysis on Categorical Data

# %%
def categorical_univariate_analysis(categorical_data):
    for x in categorical_data:
        print()
        print("*"*30,x,"*"*30)
        print(categorical_data[x].agg(["count","nunique","unique"]))
        print("Value Counts \n",categorical_data[x].value_counts())

# %%
categorical_univariate_analysis(categorical_data)
# Out:
# ****************************** sex ******************************
# count                1337
# nunique                 2
# unique     [female, male]
# Name: sex, dtype: object
# Value Counts
#  sex
# male      675
# female    662
# Name: count, dtype: int64
#
# ****************************** smoker ******************************
# count           1337
# nunique            2
# unique     [yes, no]
# Name: smoker, dtype: object
# Value Counts
#  smoker
# no     1063
# yes     274
# Name: count, dtype: int64
#
# ****************************** region ******************************
# count                                              1337
# nunique                                               4
# unique     [southwest, southeast, northwest, northeast]
# Name: region, dtype: object
# Value Counts
#  region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
def numerical_univariate_analysis(numeric_data):
    for x in numeric_data:
        print()
        print("*"*30,x,"*"*30)
        print(numeric_data[x].agg(['min', 'max', 'mean', 'median', 'std']))

# %%
numerical_univariate_analysis(numeric_data)
# Out:
# ****************************** age ******************************
# min       18.000000
# max       64.000000
# mean      39.222139
# median    39.000000
# std       14.044333
# Name: age, dtype: float64
#
# ****************************** bmi ******************************
# min       15.960000
# max       53.130000
# mean      30.663452
# median    30.400000
# std        6.100468
# Name: bmi, dtype: float64
#
# ****************************** children ******************************
# min       0.000000
# max       5.000000
# mean      1.095737
# median    1.000000
# std       1.205571
# Name: children, dtype: float64
#
# ****************************** charges ******************************
# min        1121.873900
# max       63770.428010
# mean      13279.121487
# median     9386.161300
# std       12110.359656
# Name: charges, dtype: float64

# %% [markdown]
# ## Univariate Analysis - Visual Analysis

# %%
fig=1
plt.figure(figsize=(15,18))
for col in numeric_data:
        
        
    plt.subplot(5, 3, fig)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f"Histogram of {col}")
        
    
    plt.tight_layout()
    fig+=1

# %%
fig=1
plt.figure(figsize=(15,15))
for x in numeric_data:
    plt.subplot(5,3,fig)
    sns.boxplot(df[x])
    fig+=1

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Categorical vs Categorical

# %%
categorical_data
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
df.groupby("sex")["sex"].count()
# Out:
# sex
# female    662
# male      675
# Name: sex, dtype: int64

# %%
df.groupby("smoker")["smoker"].count()
# Out:
# smoker
# no     1063
# yes     274
# Name: smoker, dtype: int64

# %%
df.groupby("region")["region"].count()
# Out:
# region
# northeast    324
# northwest    324
# southeast    364
# southwest    325
# Name: region, dtype: int64

# %%
sns.countplot(df,x="region")
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# ##  Categorical vs Numerical

# %%
def Bivariate(categorical,numerical):
    plt.figure(figsize=(20,25))
   
    fig=1
        
    for y in numerical:
        plt.subplot(10,3,fig)
        sns.violinplot(df,x="region",y=y)
        plt.xticks(rotation=45,ha='right')
        fig+=1
    plt.show()

# %%
Bivariate(categorical_data,numeric_data)

# %% [markdown]
# ##  Numerical vs Numerical

# %%
def numeric(numerical):
    for x in numerical:
        fig = 1
        plt.figure(figsize=(18, 15))
        for y in numerical:
            if x != y:  
                plt.subplot(5, 3, fig)
                sns.scatterplot(data=df, x=x, y=y)
                plt.title(f'{y} vs {x}')
                fig += 1
        plt.tight_layout()
        plt.show()

# %%
numeric(numeric_data)

# %%
def pair(numerical):
    for x in numerical:
        fig = 1
        plt.figure(figsize=(18, 15))
        for y in numerical:
            if x != y:  
                plt.subplot(5, 3, fig)
                sns.pairplot(data=df, x=x, y=y)
                plt.title(f'{y} vs {x}')
                fig += 1
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(8, 10))
sns.pairplot(numeric_data)
plt.show()

# %%
numeric_data.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109344  0.041536  0.298308
# bmi       0.109344  1.000000  0.012755  0.198401
# children  0.041536  0.012755  1.000000  0.067389
# charges   0.298308  0.198401  0.067389  1.000000

# %%
sns.heatmap(numeric_data.corr())
# Out:
# <Axes: >

# %%
plt.scatter(df["age"], df["charges"])
plt.xlabel("Age")
plt.ylabel("Charges")
plt.title("Age vs Charges")
plt.show()

# %%
numeric_data
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# %%
X=numeric_data

# %%
X.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges'], dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# Use only numeric independent features
X = df[["age", "bmi", "children" ]]

# Create a new DataFrame ONLY for VIF
vif_data = pd.DataFrame()

# Add feature names
vif_data["Feature"] = X.columns

# Calculate VIF values
vif_data["VIF"] = [
    variance_inflation_factor(X.values, i)
    for i in range(X.shape[1])
]

print(vif_data)
# Out:
#     Feature       VIF
# 0       age  7.542947
# 1       bmi  7.856685
# 2  children  1.797373

# %% [markdown]
# ## Model Building

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
X=df.drop("charges",axis=1)

# %%
X
# Out:
#       age     sex     bmi  children smoker     region
# 0      19  female  27.900         0    yes  southwest
# 1      18    male  33.770         1     no  southeast
# 2      28    male  33.000         3     no  southeast
# 3      33    male  22.705         0     no  northwest
# 4      32    male  28.880         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 1333   50    male  30.970         3     no  northwest
# 1334   18  female  31.920         0     no  northeast
# 1335   18  female  36.850         0     no  southeast
# 1336   21  female  25.800         0     no  southwest
# 1337   61  female  29.070         0    yes  northwest
#
# [1337 rows x 6 columns]

# %%
y=df[["charges"]]

# %%
y
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1337 rows x 1 columns]

# %% [markdown]
# ## Train_Test_Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=100)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1002, 6), (335, 6), (1002, 1), (335, 1))

# %% [markdown]
# ## X_train Operations  (splitting X_train to numerical and categorical)

# %%
X_train_num=X_train.select_dtypes(include=["int64","float64"])

# %%
X_train_num.head()
# Out:
#       age     bmi  children
# 1000   30  22.990         2
# 885    32  28.930         1
# 517    45  30.495         2
# 1132   57  40.280         0
# 1188   43  25.270         1

# %%
X_train_cate=X_train.select_dtypes(include=["object"])

# %%
X_train_cate.head()
# Out:
#          sex smoker     region
# 1000    male    yes  northwest
# 885     male    yes  southeast
# 517     male     no  northwest
# 1132    male     no  northeast
# 1188  female    yes  northeast

# %% [markdown]
# ## Scaling Numerical Features of X_train data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_num_transformed=pd.DataFrame(scaler.fit_transform(X_train_num),columns=X_train_num.columns,index=X_train_num.index)
X_train_num_transformed.head()
# Out:
#            age       bmi  children
# 1000 -0.644567 -1.234380  0.785181
# 885  -0.502636 -0.267219 -0.065361
# 517   0.419914 -0.012403  0.785181
# 1132  1.271498  1.580808 -0.915903
# 1188  0.277983 -0.863146 -0.065361

# %% [markdown]
# ## Scaling Categorical  Features of X_train data

# %%
X_train_cate.head()
# Out:
#          sex smoker     region
# 1000    male    yes  northwest
# 885     male    yes  southeast
# 517     male     no  northwest
# 1132    male     no  northeast
# 1188  female    yes  northeast

# %%
from sklearn.preprocessing import OneHotEncoder
ohe_encoder=OneHotEncoder(drop='first',sparse_output=False)
X_train_cate_transformed=pd.DataFrame(ohe_encoder.fit_transform(X_train_cate),
                                     columns=ohe_encoder.get_feature_names_out(X_train_cate.columns),
                                     index=X_train_cate.index)
X_train_cate_transformed.head()
# Out:
#       sex_male  smoker_yes  region_northwest  region_southeast  \
# 1000       1.0         1.0               1.0               0.0
# 885        1.0         1.0               0.0               1.0
# 517        1.0         0.0               1.0               0.0
# 1132       1.0         0.0               0.0               0.0
# 1188       0.0         1.0               0.0               0.0
#
#       region_southwest
# 1000               0.0
# 885                0.0
# 517                0.0
# 1132               0.0
# 1188               0.0

# %% [markdown]
# ## Concatenating then encoded Categorical features and rescaled Numerical Features for X_train

# %%
X_train_final=pd.concat([X_train_num_transformed,X_train_cate_transformed],axis=1)
X_train_final.head()
# Out:
#            age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 1000 -0.644567 -1.234380  0.785181       1.0         1.0               1.0
# 885  -0.502636 -0.267219 -0.065361       1.0         1.0               0.0
# 517   0.419914 -0.012403  0.785181       1.0         0.0               1.0
# 1132  1.271498  1.580808 -0.915903       1.0         0.0               0.0
# 1188  0.277983 -0.863146 -0.065361       0.0         1.0               0.0
#
#       region_southeast  region_southwest
# 1000               0.0               0.0
# 885                1.0               0.0
# 517                0.0               0.0
# 1132               0.0               0.0
# 1188               0.0               0.0

# %% [markdown]
# ## X_test Operation (splitting X_test to numerical and categorical)

# %%
X_test.head()
# Out:
#      age     sex     bmi  children smoker     region
# 12    23    male  34.400         0     no  southwest
# 306   28  female  27.500         2     no  southwest
# 318   44  female  27.645         0     no  northwest
# 816   24  female  24.225         0     no  northwest
# 157   18    male  25.175         0    yes  northeast

# %%
X_test.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region'], dtype='object')

# %%
X_test_num=X_test.select_dtypes(include=["int64","float64"])
X_test_num.head()
# Out:
#      age     bmi  children
# 12    23  34.400         0
# 306   28  27.500         2
# 318   44  27.645         0
# 816   24  24.225         0
# 157   18  25.175         0

# %%
X_test_cate=X_test.select_dtypes(include=["object"])
X_test_cate.head()
# Out:
#         sex smoker     region
# 12     male     no  southwest
# 306  female     no  southwest
# 318  female     no  northwest
# 816  female     no  northwest
# 157    male    yes  northeast

# %% [markdown]
# ## Scaling Numerical Features of X_test data

# %%
X_test_num_transformed=pd.DataFrame(scaler.transform(X_test_num),
                                   columns=X_test_num.columns,
                                   index=X_test_num.index)
X_test_num_transformed.head()
# Out:
#           age       bmi  children
# 12  -1.141324  0.623416 -0.915903
# 306 -0.786497 -0.500054  0.785181
# 318  0.348948 -0.476444 -0.915903
# 816 -1.070359 -1.033295 -0.915903
# 157 -1.496151 -0.878614 -0.915903

# %% [markdown]
# ## Scaling Categorical  Features of X_train data

# %%
X_test_cate_transformed=pd.DataFrame(ohe_encoder.transform(X_test_cate),
                                    columns=ohe_encoder.get_feature_names_out(X_test_cate.columns),
                                    index=X_test_cate.index)
X_test_cate_transformed.head()
# Out:
#      sex_male  smoker_yes  region_northwest  region_southeast  \
# 12        1.0         0.0               0.0               0.0
# 306       0.0         0.0               0.0               0.0
# 318       0.0         0.0               1.0               0.0
# 816       0.0         0.0               1.0               0.0
# 157       1.0         1.0               0.0               0.0
#
#      region_southwest
# 12                1.0
# 306               1.0
# 318               0.0
# 816               0.0
# 157               0.0

# %% [markdown]
# ## Concatenating then encoded Categorical features and rescaled Numerical Features for X_test

# %%
X_test_final=pd.concat([X_test_num_transformed,X_test_cate_transformed],axis=1)
X_test_final.head()
# Out:
#           age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 12  -1.141324  0.623416 -0.915903       1.0         0.0               0.0
# 306 -0.786497 -0.500054  0.785181       0.0         0.0               0.0
# 318  0.348948 -0.476444 -0.915903       0.0         0.0               1.0
# 816 -1.070359 -1.033295 -0.915903       0.0         0.0               1.0
# 157 -1.496151 -0.878614 -0.915903       1.0         1.0               0.0
#
#      region_southeast  region_southwest
# 12                0.0               1.0
# 306               0.0               1.0
# 318               0.0               0.0
# 816               0.0               0.0
# 157               0.0               0.0

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


def train_multiple_regressors(X_train, y_train, X_test, y_test):

    models = {
        "LinearRegression": LinearRegression(),
        "Ridge": Ridge(),
        "Lasso": Lasso(),
        "DecisionTree": DecisionTreeRegressor(random_state=42),
        "RandomForest": RandomForestRegressor(random_state=42),
        "GradientBoosting": GradientBoostingRegressor(random_state=42)
    }
    
    results = {}
    
    for name, model in models.items():
        print(f"Training {name}...")
        
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        # ✅ Correct Metrics
        mse  = mean_squared_error(y_test, y_pred)              # MSE
        rmse = mean_squared_error(y_test, y_pred, squared=False)  # RMSE
        mae  = mean_absolute_error(y_test, y_pred)             # MAE
        r2   = r2_score(y_test, y_pred)                         # R²
        
        results[name] = {
            "model": model,
            "MSE": mse,
            "RMSE": rmse,
            "MAE": mae,
            "R2_Score": r2
        }
    
    return results

# %%
results = train_multiple_regressors(X_train_final, y_train, X_test_final, y_test)

for model, scores in results.items():
    print("\nModel:", model)
    print("R2 Score:", scores["R2_Score"])
    print("RMSE:", scores["RMSE"])
    print("MAE:", scores["MAE"])
    print("MSE:", scores["MSE"])
# Out:
# Training LinearRegression...
# Training Ridge...
# Training Lasso...
# Training DecisionTree...
# Training RandomForest...
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...

# %% [markdown]
# ### 1) Linear Regression

# %%
## Model Training
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train_final,y_train)
# Out:
# LinearRegression()

# %%
## model Prediction
from sklearn import metrics

# %%
y_test_pred_LR=regressor.predict(X_test_final)
y_test_pred_LR.shape
# Out:
# (335, 1)

# %%
## Evaluation
from sklearn import metrics
y_test_pred_LR_r_score=metrics.r2_score(y_test,y_test_pred_LR)
y_test_pred_LR_mae=metrics.mean_absolute_error(y_test,y_test_pred_LR)
y_test_pred_LR_r_mse=metrics.mean_squared_error(y_test,y_test_pred_LR)
y_test_pred_LR_rmse=metrics.root_mean_squared_error(y_test,y_test_pred_LR)

print(f"R_Score={y_test_pred_LR_r_score}")
print(f"Mean Absolute Error={y_test_pred_LR_mae}")
print(f"Mean Squared Error={y_test_pred_LR_r_mse}")
print(f"Root Mean Squared Error={y_test_pred_LR_rmse}")
# Out:
# R_Score=0.7559281334086293
# Mean Absolute Error=3930.834279635717
# Mean Absolute Error=31260861.59138535
# Root Mean Squared Error=5591.141349615958

# %% [markdown]
# ### 2) Decision Tree

# %%
## Model Training
from sklearn.tree import DecisionTreeRegressor
treeregressor=DecisionTreeRegressor()
treeregressor.fit(X_train_final,y_train)
# Out:
# DecisionTreeRegressor()

# %%
## Model Prediction
from sklearn import metrics
y_test_pred_DT=treeregressor.predict(X_test_final)
y_test_pred_DT.shape
# Out:
# (335,)

# %%
## Model Evalution
from sklearn import metrics
y_test_pred_DT_r_score=metrics.r2_score(y_test,y_test_pred_DT)
y_test_pred_DT_mae=metrics.mean_absolute_error(y_test,y_test_pred_DT)
y_test_pred_DT_mse=metrics.mean_squared_error(y_test,y_test_pred_DT)
y_test_pred_DT_rmse=metrics.root_mean_squared_error(y_test,y_test_pred_DT)

print(f"R_Score={y_test_pred_DT_r_score}")
print(f"Mean Absolute Error={y_test_pred_DT_mae}")
print(f"Mean Sqaured Error={y_test_pred_DT_mse}")
print(f"Root Mean Squared Error={y_test_pred_DT_rmse}")
# Out:
# R_Score=0.6439842125249264
# Mean Absolute Error=3331.826539802985
# Mean Sqaured Error=45598701.77597854
# Root Mean Squared Error=6752.681080576703

# %% [markdown]
# ### 3) Ridge

# %%
# Model Building
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(X_train_final,y_train)
# Out:
# Ridge()

# %%
## Prediction
from sklearn import metrics
y_test_pred_Ridge=ridge.predict(X_test_final)
y_test_pred_Ridge.shape
# Out:
# (335, 1)

# %%
## Evaluation
from sklearn import metrics
y_test_pred_Ridge_R2_score=metrics.r2_score(y_test,y_test_pred_Ridge)
y_test_pred_Ridge_mae=metrics.mean_absolute_error(y_test,y_test_pred_Ridge)
y_test_pred_Ridge_mse=metrics.mean_squared_error(y_test,y_test_pred_Ridge)
y_test_pred_Ridge_rmse=metrics.root_mean_squared_error(y_test,y_test_pred_Ridge)

print(f"R2 Score= {y_test_pred_Ridge_R2_score}")
print(f"Mean Absolute Error= {y_test_pred_Ridge_mae}")
print(f"Mean Squared Error= {y_test_pred_Ridge_mse}")
print(f"Root Mean Squared Error= {y_test_pred_Ridge_rms
e}")
# Out:
# R2 Score= 0.7555879888437158
# Mean Absolute Error= 3943.5321487273227
# Mean Squared Error= 31304427.498072267
# Root Mean Squared Error= 5595.035969327835

# %% [markdown]
# ### 4) Lasso

# %%
# Model Building
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(X_train_final,y_train)
# Out:
# Lasso()

# %%
## Prediction
from sklearn import metrics
y_test_pred_Lasso=lasso.predict(X_test_final)
y_test_pred_Lasso.shape
# Out:
# (335,)

# %%
## Evaluation
from sklearn import metrics
y_test_pred_Lasso_R2_score=metrics.r2_score(y_test,y_test_pred_Lasso)
y_test_pred_Lasso_mae=metrics.mean_absolute_error(y_test,y_test_pred_Lasso)
y_test_pred_Lasso_mse=metrics.mean_squared_error(y_test,y_test_pred_Lasso)
y_test_pred_Lasso_rmse=metrics.root_mean_squared_error(y_test,y_test_pred_Lasso)

print(f"R2 Score= {y_test_pred_Lasso_R2_score}")
print(f"Mean Absolute Error= {y_test_pred_Lasso_mae}")
print(f"Mean Squared Error= {y_test_pred_Lasso_mse}")
print(f"Root Mean Squared Error= {y_test_pred_Lasso_rmse}")
# Out:
# R2 Score= 0.7558801510830448
# Mean Absolute Error= 3931.1573889150077
# Mean Squared Error= 31267007.19456311
# Root Mean Squared Error= 5591.690906565125

# %% [markdown]
# ### 4) Random Forest

# %%
# Model Building
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
random_reg=RandomForestRegressor()
random_reg.fit(X_train_final,y_train)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
## Prediction
from sklearn import metrics
y_test_pred_random_reg=random_reg.predict(X_test_final)
y_test_pred_random_reg.shape
# Out:
# (335,)

# %%
## Evaluation
from sklearn import metrics
y_test_pred_random_reg_R2_score=metrics.r2_score(y_test,y_test_pred_random_reg)
y_test_pred_random_reg_mae=metrics.mean_absolute_error(y_test,y_test_pred_random_reg)
y_test_pred_random_reg_mse=metrics.mean_squared_error(y_test,y_test_pred_random_reg)
y_test_pred_random_reg_rmse=metrics.root_mean_squared_error(y_test,y_test_pred_random_reg)

print(f"R2 Score= {y_test_pred_random_reg_R2_score}")
print(f"Mean Absolute Error= {y_test_pred_random_reg_mae}")
print(f"Mean Squared Error= {y_test_pred_random_reg_mse}")
print(f"Root Mean Squared Error= {y_test_pred_random_reg_rmse}")
# Out:
# R2 Score= 0.8427108148673608
# Mean Absolute Error= 2702.7281750672146
# Mean Squared Error= 20145687.06718394
# Root Mean Squared Error= 4488.394709379283

# %% [markdown]
# ### 5) Gradient Boosting

# %%
# Model Building
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
boosting_reg=GradientBoostingRegressor()
boosting_reg.fit(X_train_final,y_train)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor()

# %%
## Prediction
from sklearn import metrics
y_test_pred_boosting_reg=boosting_reg.predict(X_test_final)
y_test_pred_boosting_reg.shape
# Out:
# (335,)

# %%
## Evaluation
from sklearn import metrics
y_test_pred_boosting_reg_R2_score=metrics.r2_score(y_test,y_test_pred_boosting_reg)
y_test_pred_boosting_reg_mae=metrics.mean_absolute_error(y_test,y_test_pred_boosting_reg)
y_test_pred_boosting_reg_mse=metrics.mean_squared_error(y_test,y_test_pred_boosting_reg)
y_test_pred_boosting_reg_rmse=metrics.root_mean_squared_error(y_test,y_test_pred_boosting_reg)

print(f"R2 Score= {y_test_pred_boosting_reg_R2_score}")
print(f"Mean Absolute Error= {y_test_pred_boosting_reg_mae}")
print(f"Mean Squared Error= {y_test_pred_boosting_reg_mse}")
print(f"Root Mean Squared Error= {y_test_pred_boosting_reg_rmse}")
# Out:
# R2 Score= 0.8809940424523519
# Mean Absolute Error= 2285.6732075912782
# Mean Squared Error= 15242349.802141579
# Root Mean Squared Error= 3904.145207614796
